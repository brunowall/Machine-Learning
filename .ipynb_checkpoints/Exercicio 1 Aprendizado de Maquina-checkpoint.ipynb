# %% [markdown]
# ### Questão 1

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

import sklearn
from sklearn import linear_model, metrics
from sklearn import datasets
import numpy as np

# %% [markdown]
# ### Questao 2

# %%
X, y = datasets.load_diabetes(return_X_y=True)

# %%
coluna = []
for i in range(0, len(X[0])) :
    
    for j in range(0,len(X)):
        coluna.append(X[j][i])
    plt.figure(i)
    plt.title("Feature x"+str(i))
    plt.grid()
    plt.scatter(coluna, y)
    del coluna[:]

# %% [markdown]
# #### A)
# A terceira fature pois os dados estão crescente e estão menos dispersos

# %% [markdown]
# #### B)
# A segunda feature pois dados iguais tão gerando relacoes diferentes em Y

# %% [markdown]
# ### Questão 3

# %%
coluna = []
for i in range(0, len(X[0])) :
    
    for j in range(0,len(X)):
        coluna.append(X[j][i])
    print ("Correlacao x"+str(i))    
    print(np.corrcoef(coluna, y)[0, 1])
    del coluna[:]
# Out:
# Correlacao x0
# 0.18788875071891983
# Correlacao x1
# 0.04306199845160538
# Correlacao x2
# 0.5864501344746886
# Correlacao x3
# 0.44148384893088616
# Correlacao x4
# 0.2120224810145507
# Correlacao x5
# 0.17405358696874246
# Correlacao x6
# -0.39478925067091836
# Correlacao x7
# 0.43045288474477306
# Correlacao x8
# 0.5658834252428098
# Correlacao x9
# 0.38248348424858103

# %% [markdown]
# ### Questão 4

# %%
model = linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Questão 5

# %% [markdown]
# #### B0

# %%
b0 = model.intercept_
model.intercept_
# Out:
# 152.1334841628965

# %% [markdown]
# #### B1

# %%
b1 = model.coef_
model.coef_
# Out:
# array([ -10.01219782, -239.81908937,  519.83978679,  324.39042769,
#        -792.18416163,  476.74583782,  101.04457032,  177.06417623,
#         751.27932109,   67.62538639])

# %% [markdown]
# #### Formula

# %%
for i in range (0, X.shape[1]):
    f = b1[i] * X[i] + b0
    plt.plot(f)
    plt.show()

# %% [markdown]
# ### Questão 6

# %%
 y_pred  = model.predict(X)
 print(y_pred)
# Out:
# [206.11706979  68.07234761 176.88406035 166.91796559 128.45984241
#  106.34908972  73.89417947 118.85378669 158.81033076 213.58408893
#   97.07853583  95.1016223  115.06673301 164.67605023 103.07517946
#  177.17236996 211.75953205 182.84424343 147.99987605 124.01702527
#  120.33094632  85.80377894 113.11286302 252.44934852 165.48821056
#  147.72187623  97.12824075 179.09342974 129.05497324 184.78138552
#  158.71515746  69.47588393 261.50255826 112.81897436  78.37194762
#   87.66624129 207.92460213 157.87686037 240.84370686 136.93372685
#  153.48187659  74.15703284 145.63105805  77.8280105  221.0786645
#  125.22224022 142.60147066 109.4926324   73.14037106 189.87368742
#  157.93636782 169.55816531 134.18186217 157.72356219 139.1077439
#   72.73252701 207.8289973   80.10834588 104.08562488 134.57807971
#  114.23779529 180.67760064  61.12644508  98.7215441  113.79626149
#  189.96141244 148.98263155 124.33457266 114.83969622 122.00224605
# ...

# %% [markdown]
# ### Questão 7

# %%
mse = metrics.mean_squared_error(y, y_pred)
print (mse)
# Out:
# 2859.6903987680657

# %%
mse_manual = sum((y - y_pred) ** 2) / len(y)
print (mse)
# Out:
# 2859.6903987680657

# %% [markdown]
# ### Questão 8

# %%
X3 = []
for i in range(0, len(X)) :
    item = [X[i][2]]
    X3.append(item)

# %%
modeloX3 = linear_model.LinearRegression()

modeloX3.fit(X3,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(len(X3))

y_pred2  = modeloX3.predict(X3)
b1 = np.sum((X3 - np.mean(X3)) * (y_pred2 - np.mean(y_pred2))) / np.sum((X3 - np.mean(X3)) ** 2) 
print("B1  Manual")
print(b1)

b0 = np.mean(y_pred2) - b1 * np.mean(X3)

print("B0 Manual")
print (b0)
# Out:
# 442
# B1  Manual
# 1.3145040611559375e-13
# B0 Manual
# 152.13348416289594

# %%
print("B1 auto")
print(str(modeloX3.coef_)+"\n")

print("B0 auto")
print(str(modeloX3.intercept_)+"\n")
# Out:
# B1 auto
# [949.43526038]
#
# B0 auto
# 152.1334841628967

# %%
plt.grid()
plt.scatter(X3, y, color='red')
plt.plot(X3, y_pred2)

# %%
mse = metrics.mean_squared_error(y, y_pred2)
print (mse)
# Out:
# 3890.4565854612724

# %% [markdown]
# ### Questão 9

# %%
X2 = []
for i in range(0, len(X)) :
    item = [X[i][1]]
    X2.append(item)

# %%
modeloX2 = linear_model.LinearRegression()

modeloX2.fit(X2,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("B1")
print(str(modeloX2.coef_)+"\n")

print("B0")
print(str(modeloX2.intercept_)+"\n")
# Out:
# B1
# [69.71535568]
#
# B0
# 152.13348416289594

# %%
y_pred3 = modeloX2.predict(X2)
plt.grid()
plt.scatter(X2, y, color='red')
plt.plot(X2, y_pred3)

# %%
mseX2 =  metrics.mean_squared_error(y, y_pred3)
print(mseX2)
# Out:
# 5918.888899586022
